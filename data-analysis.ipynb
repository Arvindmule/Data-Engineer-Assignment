# %%
#Importing pandas and sql lite lib
import pandas as pd
import sqlite3

# %%
'''1. Data Import:
- Set up a PostgreSQL database. (You can setup a free PostgreSQL instance from Render)
- Create tables to store movie and rating data from the CSV files
(You can download the CSV files from here)
- Import the CSV data into the respective tables in the PostgreSQL database
'''
# Out:
# '1. Data Import:\n- Set up a PostgreSQL database. (You can setup a free PostgreSQL instance from Render)\n- Create tables to store movie and rating data from the CSV files\n(You can download the CSV files from here)\n- Import the CSV data into the respective tables in the PostgreSQL database\n'

# %%
#Reading movies csv file
df = pd.read_csv(r"C:\Users\SHREE\Desktop\movies_csv\movies.csv")
df
# Out:
#            id                          title  year  \
# 0     3112654                      Mea culpa  2014
# 1     1571222             A Dangerous Method  2011
# 2     2756032                 The One I Love  2014
# 3     2370248                  Short Term 12  2013
# 4       57171  Yesterday, Today and Tomorrow  1963
# ...       ...                            ...   ...
# 3138   808276                      Cold Prey  2006
# 3139    86034                      Octopussy  1983
# 3140  1286537                     Food, Inc.  2008
# 3141    64030      Anne of the Thousand Days  1969
# 3142   259516              The Poor & Hungry  2000
#
#                                country                        genre  \
# 0                               France             Action, Thriller
# 1     UK, Germany, Canada, Switzerland   Biography, Drama, Thriller
# 2                                  USA       Comedy, Drama, Romance
# 3                                  USA                        Drama
# 4                        Italy, France              Comedy, Romance
# ...                                ...                          ...
# 3138                            Norway       Drama, Horror, Mystery
# 3139                           UK, USA  Action, Adventure, Thriller
# 3140                               USA                  Documentary
# 3141                                UK               Drama, History
# 3142                               USA                        Drama
#
#                    director  minutes  \
# 0               Fred Cavayé       90
# 1          David Cronenberg       99
# 2          Charlie McDowell       91
# 3     Destin Daniel Cretton       96
# 4          Vittorio De Sica      119
# ...                     ...      ...
# 3138            Roar Uthaug       97
# 3139              John Glen      131
# 3140          Robert Kenner       94
# 3141        Charles Jarrott      145
# 3142           Craig Brewer      118
#
#                                                  poster
# 0     http://ia.media-imdb.com/images/M/MV5BNTQ0ODAw...
# 1     http://ia.media-imdb.com/images/M/MV5BMTU5Mjk3...
# 2     http://ia.media-imdb.com/images/M/MV5BMTgzODMy...
# 3     http://ia.media-imdb.com/images/M/MV5BMTEwNjE2...
# 4     http://ia.media-imdb.com/images/M/MV5BMTY0NDc4...
# ...                                                 ...
# 3138  http://ia.media-imdb.com/images/M/MV5BMjA1NDcw...
# 3139  http://ia.media-imdb.com/images/M/MV5BMjI2MDE0...
# 3140  http://ia.media-imdb.com/images/M/MV5BNDM4MjY4...
# 3141  http://ia.media-imdb.com/images/M/MV5BMTI4Mjg4...
# 3142  http://ia.media-imdb.com/images/M/MV5BMTI4OTE2...
#
# [3143 rows x 8 columns]

# %%
#Reading ratings csv file
df1 = pd.read_csv(r"C:\Users\SHREE\Desktop\movies_csv\ratings.csv")
df1
# Out:
#       rater_id  movie_id  rating        time
# 0            1     68646      10  1381620027
# 1            1    113277      10  1379466669
# 2            2    422720       8  1412178746
# 3            2    454876       8  1394818630
# 4            2    790636       7  1389963947
# ...        ...       ...     ...         ...
# 9995      1045   2310332      10  1419196605
# 9996      1046   1981115       7  1383141953
# 9997      1047     72684       9  1388742891
# 9998      1048     84649      10  1366449852
# 9999      1048   1598822       8  1366492694
#
# [10000 rows x 4 columns]

# %%
conn=sqlite3.connect("sqldb.db")

# %%
df.to_sql('movies', conn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-ea232b7a0d3f> in <module>
# ----> 1 df.to_sql('movies', conn)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1869             dtype=dtype,
#    1870         )
# -> 1871         table.create()
#    1872         table.insert(chunksize, method)
#    1873
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in create(self)
#     736         if self.exists():
#     737             if self.if_exists == "fail":
# --> 738                 raise ValueError(f"Table '{self.name}' already exists.")
#     739             elif self.if_exists == "replace":
#     740                 self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'movies' already exists.

# %%
sql_string = 'SELECT * FROM movies'
dfsql = pd.read_sql(sql_string, conn)
dfsql
# Out:
#       index       id                          title  year  \
# 0         0  3112654                      Mea culpa  2014
# 1         1  1571222             A Dangerous Method  2011
# 2         2  2756032                 The One I Love  2014
# 3         3  2370248                  Short Term 12  2013
# 4         4    57171  Yesterday, Today and Tomorrow  1963
# ...     ...      ...                            ...   ...
# 3138   3138   808276                      Cold Prey  2006
# 3139   3139    86034                      Octopussy  1983
# 3140   3140  1286537                     Food, Inc.  2008
# 3141   3141    64030      Anne of the Thousand Days  1969
# 3142   3142   259516              The Poor & Hungry  2000
#
#                                country                        genre  \
# 0                               France             Action, Thriller
# 1     UK, Germany, Canada, Switzerland   Biography, Drama, Thriller
# 2                                  USA       Comedy, Drama, Romance
# 3                                  USA                        Drama
# 4                        Italy, France              Comedy, Romance
# ...                                ...                          ...
# 3138                            Norway       Drama, Horror, Mystery
# 3139                           UK, USA  Action, Adventure, Thriller
# 3140                               USA                  Documentary
# 3141                                UK               Drama, History
# 3142                               USA                        Drama
#
#                    director  minutes  \
# 0               Fred Cavayé       90
# 1          David Cronenberg       99
# 2          Charlie McDowell       91
# 3     Destin Daniel Cretton       96
# 4          Vittorio De Sica      119
# ...                     ...      ...
# 3138            Roar Uthaug       97
# 3139              John Glen      131
# 3140          Robert Kenner       94
# 3141        Charles Jarrott      145
# 3142           Craig Brewer      118
#
#                                                  poster
# 0     http://ia.media-imdb.com/images/M/MV5BNTQ0ODAw...
# 1     http://ia.media-imdb.com/images/M/MV5BMTU5Mjk3...
# 2     http://ia.media-imdb.com/images/M/MV5BMTgzODMy...
# 3     http://ia.media-imdb.com/images/M/MV5BMTEwNjE2...
# 4     http://ia.media-imdb.com/images/M/MV5BMTY0NDc4...
# ...                                                 ...
# 3138  http://ia.media-imdb.com/images/M/MV5BMjA1NDcw...
# 3139  http://ia.media-imdb.com/images/M/MV5BMjI2MDE0...
# 3140  http://ia.media-imdb.com/images/M/MV5BNDM4MjY4...
# 3141  http://ia.media-imdb.com/images/M/MV5BMTI4Mjg4...
# 3142  http://ia.media-imdb.com/images/M/MV5BMTI4OTE2...
#
# [3143 rows x 9 columns]

# %%
df1.to_sql('ratings', conn)

# %%
sql_string1 = 'SELECT * FROM ratings'
dfsql1 = pd.read_sql(sql_string1, conn)
dfsql1
# Out:
#       index  rater_id  movie_id  rating        time
# 0         0         1     68646      10  1381620027
# 1         1         1    113277      10  1379466669
# 2         2         2    422720       8  1412178746
# 3         3         2    454876       8  1394818630
# 4         4         2    790636       7  1389963947
# ...     ...       ...       ...     ...         ...
# 9995   9995      1045   2310332      10  1419196605
# 9996   9996      1046   1981115       7  1383141953
# 9997   9997      1047     72684       9  1388742891
# 9998   9998      1048     84649      10  1366449852
# 9999   9999      1048   1598822       8  1366492694
#
# [10000 rows x 5 columns]

# %%
#Merging both movies and ratings csv file to perform oprations

# %%
df3=pd.merge(df, df1, left_index=True, right_index=True)
df3
# Out:
#            id                          title  year  \
# 0     3112654                      Mea culpa  2014
# 1     1571222             A Dangerous Method  2011
# 2     2756032                 The One I Love  2014
# 3     2370248                  Short Term 12  2013
# 4       57171  Yesterday, Today and Tomorrow  1963
# ...       ...                            ...   ...
# 3138   808276                      Cold Prey  2006
# 3139    86034                      Octopussy  1983
# 3140  1286537                     Food, Inc.  2008
# 3141    64030      Anne of the Thousand Days  1969
# 3142   259516              The Poor & Hungry  2000
#
#                                country                        genre  \
# 0                               France             Action, Thriller
# 1     UK, Germany, Canada, Switzerland   Biography, Drama, Thriller
# 2                                  USA       Comedy, Drama, Romance
# 3                                  USA                        Drama
# 4                        Italy, France              Comedy, Romance
# ...                                ...                          ...
# 3138                            Norway       Drama, Horror, Mystery
# 3139                           UK, USA  Action, Adventure, Thriller
# 3140                               USA                  Documentary
# 3141                                UK               Drama, History
# 3142                               USA                        Drama
#
#                    director  minutes  \
# 0               Fred Cavayé       90
# 1          David Cronenberg       99
# 2          Charlie McDowell       91
# 3     Destin Daniel Cretton       96
# 4          Vittorio De Sica      119
# ...                     ...      ...
# 3138            Roar Uthaug       97
# 3139              John Glen      131
# 3140          Robert Kenner       94
# 3141        Charles Jarrott      145
# 3142           Craig Brewer      118
#
#                                                  poster  rater_id  movie_id  \
# 0     http://ia.media-imdb.com/images/M/MV5BNTQ0ODAw...         1     68646
# 1     http://ia.media-imdb.com/images/M/MV5BMTU5Mjk3...         1    113277
# 2     http://ia.media-imdb.com/images/M/MV5BMTgzODMy...         2    422720
# 3     http://ia.media-imdb.com/images/M/MV5BMTEwNjE2...         2    454876
# 4     http://ia.media-imdb.com/images/M/MV5BMTY0NDc4...         2    790636
# ...                                                 ...       ...       ...
# 3138  http://ia.media-imdb.com/images/M/MV5BMjA1NDcw...       331    790636
# 3139  http://ia.media-imdb.com/images/M/MV5BMjI2MDE0...       331    790724
# 3140  http://ia.media-imdb.com/images/M/MV5BNDM4MjY4...       331    993846
# 3141  http://ia.media-imdb.com/images/M/MV5BMTI4Mjg4...       331   1001508
# 3142  http://ia.media-imdb.com/images/M/MV5BMTI4OTE2...       331   1020072
#
#       rating        time
# 0         10  1381620027
# 1         10  1379466669
# 2          8  1412178746
# 3          8  1394818630
# 4          7  1389963947
# ...      ...         ...
# 3138       8  1392520368
# 3139       7  1388978089
# 3140       8  1391960142
# 3141       7  1369017061
# 3142       7  1428010657
#
# [3143 rows x 12 columns]

# %%
'''
a. Top 5 Movie Titles: Sort and print the top 5 movie titles based on the following criteria:
● Duration
'''

# %%
dur=df3.sort_values(by=['minutes'],ascending=False)
dur[['title']].head(5)
# Out:
#                             title
# 903            Gangs of Wasseypur
# 1065           Gone with the Wind
# 157   Once Upon a Time in America
# 434            Lawrence of Arabia
# 2595                 Jodhaa Akbar

# %%
'''
a. Top 5 Movie Titles: Sort and print the top 5 movie titles based on the following criteria:
● Year of Release
'''

# %%
release_date=df3.sort_values(by=['year'],ascending=False)
release_date[['title']].head(5)
# Out:
#                       title
# 1855                 Maggie
# 2142                Tracers
# 1157                 Hidden
# 2320  They Look Like People
# 1145       Hitman: Agent 47

# %%
'''
a. Top 5 Movie Titles: Sort and print the top 5 movie titles based on the following criteria:
● Average rating (consider movies with minimum 5 ratings)
'''

# %%
avg_rating=df3.sort_values(by=['rating'],ascending=False)
avg_rating=avg_rating[avg_rating.rating >= 5]
avg_rating[['title']].head(5)
# Out:
#              title
# 0        Mea culpa
# 1962   All at Once
# 1998       Win Win
# 1997      Swingers
# 1994  Vivre Sa Vie

# %%
'''b. Number of Unique Raters: Determine and
print the count of unique rater IDs
'''

# %%
uni_rater=df3['rater_id'].drop_duplicates()
uni_rater
# Out:
# 0         1
# 2         2
# 22        3
# 24        4
# 25        5
#        ...
# 3110    327
# 3112    328
# 3113    329
# 3122    330
# 3130    331
# Name: rater_id, Length: 331, dtype: int64

# %%
print("Number of unique records",uni_rater.shape[0])
# Out:
# Number of unique records 331

# %%
'''
c. Top 5 Rater IDs: Sort and print the top 5 rater IDs based on:
● Most movies rated
'''

# %%
ratings_count = df3['rater_id'].value_counts()
ratings_count.head(5)
# Out:
# 82     159
# 51     143
# 193    119
# 314    110
# 323    102
# Name: rater_id, dtype: int64

# %%
'''
c. Top 5 Rater IDs: Sort and print the top 5 rater IDs based on:
● Highest Average rating given (consider raters with min 5 ratings)
'''

# %%
qualified_raters = ratings_count[ratings_count >= 5].index.tolist()
avg_ratings = df3.groupby('rater_id')['rating'].mean()
top_raters_highest_avg = avg_ratings.loc[qualified_raters].nlargest(5)
top_raters_highest_avg
# Out:
# rater_id
# 146    10.000000
# 231    10.000000
# 256    10.000000
# 206    10.000000
# 103     9.916667
# Name: rating, dtype: float64

# %%
'''
d. Top Rated Movie:
- Find and print the top-rated movies by:
● Director 'Michael Bay'
'''

# %%
filtered_movies = df3[(df3['director'] == 'Michael Bay')]
filtered_movies.sort_values(by=['rating'],ascending=False)
filtered_movies=filtered_movies[filtered_movies.rating >=7]
filtered_movies[['title']].head(5)
# Out:
#                                     title
# 119                            Armageddon
# 163                          Pearl Harbor
# 812                              The Rock
# 1288      Transformers: Age of Extinction
# 1644  Transformers: Revenge of the Fallen

# %%
'''
d. Top Rated Movie:
- Find and print the top-rated movies by:
● 'Comedy'
'''

# %%
filtered_movies1 = df3[(df['genre'] == 'Comedy')]
filtered_movies1.sort_values(by=['rating'],ascending=False)
filtered_movies1=filtered_movies1[filtered_movies1.rating == 10]
filtered_movies1[['title']].head(5)
# Out:
#                         title
# 76                  Airplane!
# 118                  Marry Me
# 129                  Gorko! 2
# 297           The Dinner Game
# 770  For a Good Time, Call...

# %%
'''
d. Top Rated Movie:
- Find and print the top-rated movies by:
● In the year 2013
'''

# %%
filtered_movies2 = df3[(df['year'] == 2013)]
filtered_movies2.sort_values(by=['rating'],ascending=False)
filtered_movies2=filtered_movies2[filtered_movies2.rating == 10]
filtered_movies2[['title']].head(5)
# Out:
#                             title
# 13   The House at the End of Time
# 36                     Dirty Wars
# 117                 The Sacrament
# 153                         RED 2
# 214                           Joe

# %%
'''
d. Top Rated Movie:
- Find and print the top-rated movies by:
● In India (consider movies with a minimum of 5 ratings).
'''

# %%
filtered_movies3 = df3[(df['country'] == 'India')]
filtered_movies3.sort_values(by=['rating'],ascending=False)
filtered_movies3=filtered_movies3[filtered_movies3.rating == 10]
filtered_movies3[['title']].head(5)
# Out:
#                           title
# 127    Zindagi Na Milegi Dobara
# 371                      Barfi!
# 1534                 Khoobsurat
# 1574          Bajrangi Bhaijaan
# 1587  Get Educated: Paathshaala

# %%
'''e. Favorite Movie Genre of Rater ID 1040: Determine and print the favorite movie genre
for the rater with ID 1040 (defined as the genre of the movie the rater has rated most often).
'''

# %%
ratings_1040 = df3[df3['rater_id'] == 104]
genre_counts = ratings_1040['genre'].value_counts()
favorite_genre = genre_counts.idxmax()
favorite_genre
# Out:
# 'Documentary'

# %%
'''f. Highest Average Rating for a Movie Genre by Rater ID 1040: Find and print the
highest average rating for a movie genre given by the rater with ID 1040 (consider genres with a
minimum of 5 ratings).
'''

# %%
ratings_1040 = df3[df3['rater_id'] == 104]
genre_ratings_count = ratings_1040['genre'].value_counts()
qualified_genres = genre_ratings_count[genre_ratings_count >= 5].index.tolist()
qualified_ratings = ratings_1040[ratings_1040['genre'].isin(qualified_genres)]
avg_ratings_per_genre = qualified_ratings.groupby('genre')['rating'].mean()
highest_avg_rating = avg_ratings_per_genre.max()
highest_avg_rating
# Out:
# nan

# %%
'''g. Year with Second-Highest Number of Action Movies: Identify and print the year with
the second-highest number of action movies from the USA that received an average rating of
6.5 or higher and had a runtime of less than 120 minutes.
'''

# %%
year_counts = df3['year'].value_counts()
sorted_years = year_counts.sort_values(ascending=False)
second_highest_year = sorted_years.index[1]
second_highest_year
# Out:
# 2014

# %%
'''
h. Count of Movies with High Ratings: Count and print the number of movies that have
received at least five reviews with a rating of 7 or higher.
'''

# %%
high_ratings_count = df3[df3['rating'] >= 7].groupby('title')['rating'].count()
qualified_movies = high_ratings_count[high_ratings_count >= 5]
num_qualified_movies = len(qualified_movies)
num_qualified_movies
# Out:
# 0
